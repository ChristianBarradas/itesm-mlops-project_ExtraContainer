# %% [markdown]
# <hr/>
#
# # Predicting House Prices (Keras - Artificial Neural Network)
# **[by Tomas Mantero](https://www.kaggle.com/tomasmantero)**
# <hr/>
#
# ### Table of Contents
# 1. [Overview](#ch1)
# 1. [Dataset](#ch2)
# 1. [Exploratory Data Analysis](#ch3)
# 1. [Working with Feature Data](#ch4)
# 1. [Feature Engineering](#ch5)
# 1. [Scaling and Train Test Split](#ch6)
# 1. [Creating a Model](#ch7)
# 1. [Training the Model](#ch8)
# 1. [Evaluation on Test Data](#ch9)
# 1. [Predicting on a Brand New House](#ch10)

# %%
# !pip install -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt
# Out:
# Requirement already satisfied: absl-py==1.4.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: asttokens==2.2.1 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: backcall==0.2.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: cachetools==5.3.1 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 5)) (5.3.1)
# Requirement already satisfied: certifi==2023.7.22 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 6)) (2023.7.22)
# Requirement already satisfied: charset-normalizer==3.2.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: colorama==0.4.6 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: comm==0.1.4 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 9)) (0.1.4)
# Requirement already satisfied: contourpy==1.1.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: cycler==0.11.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 11)) (0.11.0)
# Collecting debugpy==1.6.7 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 12))
#   Using cached debugpy-1.6.7-cp310-cp310-win_amd64.whl (4.8 MB)
# Requirement already satisfied: decorator==5.1.1 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 13)) (5.1.1)
# Requirement already satisfied: executing==1.2.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 14)) (1.2.0)
# Requirement already satisfied: flatbuffers==23.5.26 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 15)) (23.5.26)
# Requirement already satisfied: fonttools==4.42.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 16)) (4.42.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 17)) (0.4.0)
# Requirement already satisfied: google-auth==2.22.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 18)) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib==1.0.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 19)) (1.0.0)
# Requirement already satisfied: google-pasta==0.2.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 20)) (0.2.0)
# Collecting grpcio==1.56.2 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 21))
#   Obtaining dependency information for grpcio==1.56.2 from https://files.pythonhosted.org/packages/3f/fe/b332c682f682745230083023935a06f21e029cb8ef01900531a89b47217c/grpcio-1.56.2-cp310-cp310-win_amd64.whl.metadata
#   Using cached grpcio-1.56.2-cp310-cp310-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: h5py==3.9.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 22)) (3.9.0)
# Requirement already satisfied: idna==3.4 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 23)) (3.4)
# Requirement already satisfied: ipykernel==6.25.1 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 24)) (6.25.1)
# Requirement already satisfied: ipython==8.14.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 25)) (8.14.0)
# Requirement already satisfied: jedi==0.19.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 26)) (0.19.0)
# Collecting joblib==1.3.1 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 27))
#   Obtaining dependency information for joblib==1.3.1 from https://files.pythonhosted.org/packages/28/08/9dcdaa5aac4634e4c23af26d92121f7ce445c630efa0d3037881ae2407fb/joblib-1.3.1-py3-none-any.whl.metadata
#   Using cached joblib-1.3.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: jupyter_client==8.3.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 28)) (8.3.0)
# Requirement already satisfied: jupyter_core==5.3.1 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 29)) (5.3.1)
# Requirement already satisfied: keras==2.13.1 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 30)) (2.13.1)
# Requirement already satisfied: kiwisolver==1.4.4 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 31)) (1.4.4)
# Requirement already satisfied: libclang==16.0.6 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 32)) (16.0.6)
# Requirement already satisfied: Markdown==3.4.4 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 33)) (3.4.4)
# Requirement already satisfied: MarkupSafe==2.1.3 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 34)) (2.1.3)
# Requirement already satisfied: matplotlib==3.7.2 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 35)) (3.7.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 36)) (0.1.6)
# Requirement already satisfied: nest-asyncio==1.5.7 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 37)) (1.5.7)
# Requirement already satisfied: numpy==1.24.3 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 38)) (1.24.3)
# Requirement already satisfied: oauthlib==3.2.2 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 39)) (3.2.2)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 40)) (3.3.0)
# Requirement already satisfied: packaging==23.1 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 41)) (23.1)
# Requirement already satisfied: pandas==2.0.3 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 42)) (2.0.3)
# Requirement already satisfied: parso==0.8.3 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 43)) (0.8.3)
# Requirement already satisfied: pickleshare==0.7.5 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 44)) (0.7.5)
# Requirement already satisfied: Pillow==10.0.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 45)) (10.0.0)
# Requirement already satisfied: platformdirs==3.10.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 46)) (3.10.0)
# Requirement already satisfied: prompt-toolkit==3.0.39 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 47)) (3.0.39)
# Collecting protobuf==4.23.4 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 48))
#   Obtaining dependency information for protobuf==4.23.4 from https://files.pythonhosted.org/packages/80/70/dc63d340d27b8ff22022d7dd14b8d6d68b479a003eacdc4507150a286d9a/protobuf-4.23.4-cp310-abi3-win_amd64.whl.metadata
#   Using cached protobuf-4.23.4-cp310-abi3-win_amd64.whl.metadata (540 bytes)
# Requirement already satisfied: psutil==5.9.5 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 49)) (5.9.5)
# Requirement already satisfied: pure-eval==0.2.2 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 50)) (0.2.2)
# Requirement already satisfied: pyasn1==0.5.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 51)) (0.5.0)
# Requirement already satisfied: pyasn1-modules==0.3.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 52)) (0.3.0)
# Requirement already satisfied: Pygments==2.16.1 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 53)) (2.16.1)
# Requirement already satisfied: pyparsing==3.0.9 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 54)) (3.0.9)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 55)) (2.8.2)
# Requirement already satisfied: pytz==2023.3 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 56)) (2023.3)
# Requirement already satisfied: pywin32==306 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 57)) (306)
# Collecting pyzmq==25.1.0 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 58))
#   Obtaining dependency information for pyzmq==25.1.0 from https://files.pythonhosted.org/packages/32/e4/ce4f94009f84c2a688082c2674d490d2e20e0c9058087f5358a2bf29ddf1/pyzmq-25.1.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached pyzmq-25.1.0-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: requests==2.31.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 59)) (2.31.0)
# Requirement already satisfied: requests-oauthlib==1.3.1 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 60)) (1.3.1)
# Requirement already satisfied: rsa==4.9 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 61)) (4.9)
# Requirement already satisfied: scikit-learn==1.3.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 62)) (1.3.0)
# Requirement already satisfied: scipy==1.11.1 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 63)) (1.11.1)
# Requirement already satisfied: seaborn==0.12.2 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 64)) (0.12.2)
# Requirement already satisfied: six==1.16.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 65)) (1.16.0)
# Collecting sklearn==0.0.post7 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 66))
#   Using cached sklearn-0.0.post7-py3-none-any.whl
# Requirement already satisfied: stack-data==0.6.2 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 67)) (0.6.2)
# Requirement already satisfied: tensorboard==2.13.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 68)) (2.13.0)
# Requirement already satisfied: tensorboard-data-server==0.7.1 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 69)) (0.7.1)
# Requirement already satisfied: tensorflow==2.13.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 70)) (2.13.0)
# Requirement already satisfied: tensorflow-estimator==2.13.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 71)) (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 72)) (2.13.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.31.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 73)) (0.31.0)
# Requirement already satisfied: termcolor==2.3.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 74)) (2.3.0)
# Requirement already satisfied: threadpoolctl==3.2.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 75)) (3.2.0)
# Collecting tornado==6.3.2 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 76))
#   Obtaining dependency information for tornado==6.3.2 from https://files.pythonhosted.org/packages/de/fa/b8b2ee2f528eedd03d98d49c76822f065f18e99f6f58c1e18fe5ed893098/tornado-6.3.2-cp38-abi3-win_amd64.whl.metadata
#   Using cached tornado-6.3.2-cp38-abi3-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: traitlets==5.9.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 77)) (5.9.0)
# Collecting typing_extensions==4.5.0 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 78))
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: tzdata==2023.3 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 79)) (2023.3)
# Requirement already satisfied: urllib3==1.26.16 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 80)) (1.26.16)
# Requirement already satisfied: wcwidth==0.2.6 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 81)) (0.2.6)
# Requirement already satisfied: Werkzeug==2.3.6 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 82)) (2.3.6)
# Requirement already satisfied: wrapt==1.15.0 in c:\users\sistemas\mlops-project\env\lib\site-packages (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 83)) (1.15.0)
# Collecting holoviews==1.15.4 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 84))
#   Using cached holoviews-1.15.4-py2.py3-none-any.whl (4.3 MB)
# Collecting html5lib==1.1 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 85))
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Collecting httpimport==1.3.1 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 86))
#   Obtaining dependency information for httpimport==1.3.1 from https://files.pythonhosted.org/packages/bb/86/d9744a971602522d214bc933463d5fddef2716a689129587d29ac9a59f1c/httpimport-1.3.1-py2.py3-none-any.whl.metadata
#   Using cached httpimport-1.3.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting httplib2==0.21.0 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 87))
#   Using cached httplib2-0.21.0-py3-none-any.whl (96 kB)
# Collecting humanize==4.6.0 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 88))
#   Using cached humanize-4.6.0-py3-none-any.whl (109 kB)
# Collecting hyperopt==0.2.7 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 89))
#   Using cached hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
# Collecting imageio==2.25.1 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 91))
#   Using cached imageio-2.25.1-py3-none-any.whl (3.4 MB)
# Collecting imageio-ffmpeg==0.4.8 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 92))
#   Using cached imageio_ffmpeg-0.4.8-py3-none-win_amd64.whl (22.6 MB)
# Collecting imagesize==1.4.1 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 93))
#   Using cached imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Collecting imbalanced-learn==0.10.1 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 94))
#   Using cached imbalanced_learn-0.10.1-py3-none-any.whl (226 kB)
# Collecting imgaug==0.4.0 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 95))
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# Collecting importlib-metadata==4.6.4 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 96))
#   Using cached importlib_metadata-4.6.4-py3-none-any.whl (17 kB)
# Collecting importlib-resources==6.0.0 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 97))
#   Obtaining dependency information for importlib-resources==6.0.0 from https://files.pythonhosted.org/packages/29/d1/bed03eca30aa05aaf6e0873de091f9385c48705c4a607c2dfe3edbe543e8/importlib_resources-6.0.0-py3-none-any.whl.metadata
#   Using cached importlib_resources-6.0.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting imutils==0.5.4 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 98))
#   Using cached imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting inflect==6.0.5 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 99))
#   Obtaining dependency information for inflect==6.0.5 from https://files.pythonhosted.org/packages/a2/73/17b439e7f18b84ca63e4b85160e9305898b778dc94ef746e33557e2de902/inflect-6.0.5-py3-none-any.whl.metadata
#   Using cached inflect-6.0.5-py3-none-any.whl.metadata (21 kB)
# Collecting iniconfig==2.0.0 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 100))
#   Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting intel-openmp==2023.2.0 (from -r C:\Users\SISTEMAS\MLOPs_Project\requirements.txt (line 101))
#   Obtaining dependency information for intel-openmp==2023.2.0 from https://files.pythonhosted.org/packages/8a/e5/f28d836dc78a8bc9e58e424f133b5cc5f0ba9e88591a04f9bd2bbfe2c6d6/intel_openmp-2023.2.0-py2.py3-none-win_amd64.whl.metadata
#   Using cached intel_openmp-2023.2.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
#
# The conflict is caused by:
#     The user requested ipykernel==6.25.1
#     The user requested ipykernel==5.5.6
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
# ERROR: Cannot install ipykernel==5.5.6 and ipykernel==6.25.1 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts

# %% [markdown]
# <a id="ch1"></a>
# ## Overview
# <hr/>
#
# One of the objectives of this notebook is to **show step-by-step how to analyze and visualize the dataset to predict future home prices.** Moreover, we are going to explain most of the concepts used so that you understand why we are using them.
# In base of features like sqft_living, bathrooms, bedrooms, view, and others, we are going to build a deep learning model that can predict future price houses.
#
# If you have a question or feedback, do not hesitate to write and if you like this kernel,<b><font color='green'> please upvote! </font></b>
#
# <img src="https://images.pexels.com/photos/1546168/pexels-photo-1546168.jpeg?auto=compress&cs=tinysrgb&dpr=3&h=750&w=1260" title="source: www.pexels.com" />
# <br>
#
# The following questions will be answered throughout the Kernel:
# * ***Which features are available in the dataset?***
# * ***Which features are categorical?***
# * ***Which features are numerical?***
# * ***Which features contain blank, null or empty values?***
# * ***What are the data types for various features?***
# * ***What is the distribution of numerical feature values across the samples?***
# * ***Which features are more correlated to the price?***

# %% [markdown]
# <a id="ch2"></a>
# ## Dataset
# <hr/>
#
# * This dataset contains house sale prices for King County, which includes Seattle.
# * It includes homes sold between May 2014 and May 2015.
# * 21 columns. (features)
# * 21597 rows.
#
# ***Feature Columns***
#
# * **id:** Unique ID for each home sold
# * **date:** Date of the home sale
# * **price:** Price of each home sold
# * **bedrooms:** Number of bedrooms
# * **bathrooms:** Number of bathrooms, where .5 accounts for a room with a toilet but no shower
# * **sqft_living:** Square footage of the apartments interior living space
# * **sqft_lot:** Square footage of the land space
# * **floors:** Number of floors
# * **waterfront:** - A dummy variable for whether the apartment was overlooking the waterfront or not
# * **view:** An index from 0 to 4 of how good the view of the property was
# * **condition:** - An index from 1 to 5 on the condition of the apartment,
# * **grade:** An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
# * **sqft_above:** The square footage of the interior housing space that is above ground level
# * **sqft_basement:** The square footage of the interior housing space that is below ground level
# * **yr_built:** The year the house was initially built
# * **yr_renovated:** The year of the house’s last renovation
# * **zipcode:** What zipcode area the house is in
# * **lat:** Lattitude
# * **long:** Longitude
# * **sqft_living15:** The square footage of interior housing living space for the nearest 15 neighbors
# * **sqft_lot15:** The square footage of the land lots of the nearest 15 neighbors

# %% [markdown]
# ### Imports

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# scaling and train test split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# creating a model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# evaluation on test data
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# ### Acquire data
# The Python Pandas packages helps us work with our datasets. We start by acquiring the datasets into Pandas DataFrames.

# %%
df = pd.read_csv('/Users/SISTEMAS/MLOPs_Project/DataSet/kc_house_data.csv')

# %% [markdown]
# ### Analyze by describing data
# Pandas also helps describe the datasets answering following questions early in our project.
#
# ***Which features are available in the dataset?***

# %%
print(df.columns.values)
# Out:
# ['id' 'date' 'price' 'bedrooms' 'bathrooms' 'sqft_living' 'sqft_lot'
#  'floors' 'waterfront' 'view' 'condition' 'grade' 'sqft_above'
#  'sqft_basement' 'yr_built' 'yr_renovated' 'zipcode' 'lat' 'long'
#  'sqft_living15' 'sqft_lot15']

# %% [markdown]
# ***Which features are categorical?***
#
# These values classify the samples into sets of similar samples. Within categorical features are the values nominal, ordinal, ratio, or interval based? Among other things this helps us select the appropriate plots for visualization.
#
# * Categorical: id, waterfront, zipcode.
#
# ***Which features are numerical?***
#
# Which features are numerical? These values change from sample to sample. Within numerical features are the values discrete, continuous, or timeseries based? Among other things this helps us select the appropriate plots for visualization.
#
# * Continous: price, bathrooms, floors, lat, long.
# * Discrete: date, bedrooms, sqft_living, sqft_lot, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, sqft_living15, sqft_lot15.

# %%
# preview the data
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
# preview the data
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [5 rows x 21 columns]

# %% [markdown]
# ***Which features contain blank, null or empty values?***
#
# We can check for missing values with pandas isnull(). This indicates whether values are missing or not. Then we can sum all the values to check every column.

# %%
# No missing values
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ***What are the data types for various features?***
#
# Five features are floats, fifteen are integers and one is an object.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ***What is the distribution of numerical feature values across the samples?***

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %% [markdown]
# ### Assumtions based on data analysis
#
# We arrive at following assumptions based on data analysis done so far. We may validate these assumptions further before taking appropriate actions.
#
# ### Correlating
#
# We want to know how well does each feature correlate with Price. We want to do this early in our project and match these quick correlations with modelled correlations later in the project.
#
# ### Completing
#
# Since there are no missing values we do not need to complete any values.
#
# ### Correcting
#
# Id feature may be dropped from our analysis since it does not add value.
# Date feature may be dropped since we are going to do feature engineering and make a year and month column.
# Zipcode feature is a special case, we could use it, but since we do not know exactly the zones of King County we are just going to drop it.
#
# ### Creating
#
# We may want to create a new feature called Year based on Date to analyze the price change throughout the years.
# We may want to create a new feature called Month based on Date to analyze the price change throughout the months.

# %% [markdown]
# <a id="ch3"></a>
# ## Exploratory Data Analysis
# <hr/>
#
# ### Analyze by visualizing data
# Now we can continue confirming some of our assumptions using visualizations for analyzing the data.

# %% [markdown]
# ### Pearson correlation matrix
# We use the Pearson correlation coefficient to examine the strength and direction of the linear relationship between two continuous variables.
#
# The correlation coefficient can range in value from −1 to +1. The larger the absolute value of the coefficient, the stronger the relationship between the variables. For the Pearson correlation, an absolute value of 1 indicates a perfect linear relationship. A correlation close to 0 indicates no linear relationship between the variables.
#
# The sign of the coefficient indicates the direction of the relationship. If both variables tend to increase or decrease together, the coefficient is positive, and the line that represents the correlation slopes upward. If one variable tends to increase as the other decreases, the coefficient is negative, and the line that represents the correlation slopes downward.

# %%
df1 = df.drop(['date'], axis = 1)
df1
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0         1.0           0     0          3      7        1180              0
# 1         2.0           0     0          3      7        2170            400
# 2         1.0           0     0          3      6         770              0
# 3         1.0           0     0          5      7        1050            910
# 4         1.0           0     0          3      8        1680              0
# ...       ...         ...   ...        ...    ...         ...            ...
# 21608     3.0           0     0          3      8        1530              0
# 21609     2.0           0     0          3      8        2310              0
# 21610     2.0           0     0          3      7        1020              0
# 21611     2.0           0     0          3      8        1600              0
# 21612     2.0           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1955             0    98178  47.5112 -122.257           1340
# 1          1951          1991    98125  47.7210 -122.319           1690
# 2          1933             0    98028  47.7379 -122.233           2720
# 3          1965             0    98136  47.5208 -122.393           1360
# 4          1987             0    98074  47.6168 -122.045           1800
# ...         ...           ...      ...      ...      ...            ...
# 21608      2009             0    98103  47.6993 -122.346           1530
# 21609      2014             0    98146  47.5107 -122.362           1830
# 21610      2009             0    98144  47.5944 -122.299           1020
# 21611      2004             0    98027  47.5345 -122.069           1410
# 21612      2008             0    98144  47.5941 -122.299           1020
#
#        sqft_lot15
# 0            5650
# 1            7639
# 2            8062
# 3            5000
# 4            7503
# ...           ...
# 21608        1509
# 21609        7200
# 21610        2007
# 21611        1287
# 21612        1357
#
# [21613 rows x 20 columns]

# %%
sns.set(style="whitegrid", font_scale=1)

plt.figure(figsize=(13,13))
plt.title('Pearson Correlation Matrix',fontsize=25)
sns.heatmap(df1.corr(),linewidths=0.25,vmax=0.7,square=True,cmap="GnBu",linecolor='w',annot=True, annot_kws={"size":7}, cbar_kws={"shrink": .7})
# Out:
# <Axes: title={'center': 'Pearson Correlation Matrix'}>

# %% [markdown]
# ### Price correlation
# * This allow us to explore labels that are highly correlated to the price.
# * sqft_living looks like a highly correlated label to the price, as well as grade, sqft_above, sqft_living15 and bathrooms.
#
# ***Which features are more correlated to the price?***

# %%
price_corr = df1.corr()['price'].sort_values(ascending=False)
print(price_corr)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %% [markdown]
# ### Price feature
# * Most of the house prices are between \\$0 and \\$1,500,000.
# * The average house price is \\$540,000.
# * Keep in mind that it may be a good idea to drop extreme values. For instance, we could focus on house from \\$0 to \\$3,000,000 and drop the other ones.
# * It seems that there is a positive linear relationship between the price and sqft_living.
# * An increase in living space generally corresponds to an increase in house price.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.distplot(df['price'], ax=axes[0])
sns.scatterplot(x='price',y='sqft_living', data=df, ax=axes[1])
sns.despine(bottom=True, left=True)
axes[0].set(xlabel='Price in millions [USD]', ylabel='', title='Price Distribuition')
axes[1].set(xlabel='Price', ylabel='Sqft Living', title='Price vs Sqft Living')
axes[1].yaxis.set_label_position("right")
axes[1].yaxis.tick_right()
# Out:
# C:\Users\SISTEMAS\AppData\Local\Temp\ipykernel_37880\636539046.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'], ax=axes[0])

# %% [markdown]
# ### Bedrooms and floors box plots
# Box plot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending from the boxes (whiskers) indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot. Outliers may be plotted as individual points. The spacings between the different parts of the box indicate the degree of dispersion (spread).
#
# * We can see outliers plotted as individual points; this probably are the more expensive houses.
# * We can see that the price tends to go up when the house has more bedrooms.

# %%
sns.set(style="whitegrid", font_scale=1)

f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x=df['bedrooms'],y=df['price'], ax=axes[0])
sns.boxplot(x=df['floors'],y=df['price'], ax=axes[1])
sns.despine(bottom=True, left=True)
axes[0].set(xlabel='Bedrooms', ylabel='Price', title='Bedrooms vs Price Box Plot')
axes[1].set(xlabel='Floors', ylabel='Price', title='Floors vs Price Box Plot')
# Out:
# [Text(0.5, 0, 'Floors'),
#  Text(0, 0.5, 'Price'),
#  Text(0.5, 1.0, 'Floors vs Price Box Plot')]

# %% [markdown]
# ### Waterfront, view and grade box plots
# * Waterfront houses tends to have a better price value.
# * The price of waterfront houses tends to be more disperse and the price of houses without waterfront tend to be more concentrated.
# * Grade and waterfront effect price. View seem to effect less but it also has an effect on price.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x=df['waterfront'],y=df['price'], ax=axes[0])
sns.boxplot(x=df['view'],y=df['price'], ax=axes[1])
sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Waterfront', ylabel='Price', title='Waterfront vs Price Box Plot')
axes[1].set(xlabel='View', ylabel='Price', title='View vs Price Box Plot')

f, axe = plt.subplots(1, 1,figsize=(15,5))
sns.boxplot(x=df['grade'],y=df['price'], ax=axe)
sns.despine(left=True, bottom=True)
axe.set(xlabel='Grade', ylabel='Price', title='Grade vs Price Box Plot')
# Out:
# [Text(0.5, 0, 'Grade'),
#  Text(0, 0.5, 'Price'),
#  Text(0.5, 1.0, 'Grade vs Price Box Plot')]

# %% [markdown]
# <a id="ch4"></a>
# ## Working with Feature Data
# <hr/>
#
# ### Correcting by dropping features
# By dropping features, we are dealing with fewer data points. Speeds up our notebook and eases the analysis. Based on our assumptions and decisions we want to drop the Id, zipcode and Date features.

# %%
df = df.drop('id', axis=1)
df = df.drop('zipcode',axis=1)

# %% [markdown]
# <a id="ch5"></a>
# ## Feature engineering
# <hr/>
#
# We want to engineer the date feature to make a year and month column. The feature date is as a string. With pd.to_datetime we can convert an argument to datetime.

# %%
df['date'] = pd.to_datetime(df['date'])

df['month'] = df['date'].apply(lambda date:date.month)
df['year'] = df['date'].apply(lambda date:date.year)

df = df.drop('date',axis=1)

# Check the new columns
print(df.columns.values)
# Out:
# ['price' 'bedrooms' 'bathrooms' 'sqft_living' 'sqft_lot' 'floors'
#  'waterfront' 'view' 'condition' 'grade' 'sqft_above' 'sqft_basement'
#  'yr_built' 'yr_renovated' 'lat' 'long' 'sqft_living15' 'sqft_lot15'
#  'month' 'year']

# %% [markdown]
# ### House price trends
# * Looking the box plots we notice that there is not a big difference between 2014 and 2015.
# * The number of houses sold by month tends to be similar every month.
# * The line plot show that around April there is an increase in house prices.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x='year',y='price',data=df, ax=axes[0])
sns.boxplot(x='month',y='price',data=df, ax=axes[1])
sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Year', ylabel='Price', title='Price by Year Box Plot')
axes[1].set(xlabel='Month', ylabel='Price', title='Price by Month Box Plot')

f, axe = plt.subplots(1, 1,figsize=(15,5))
df.groupby('month').mean()['price'].plot()
sns.despine(left=True, bottom=True)
axe.set(xlabel='Month', ylabel='Price', title='Price Trends')
# Out:
# [Text(0.5, 0, 'Month'), Text(0, 0.5, 'Price'), Text(0.5, 1.0, 'Price Trends')]

# %% [markdown]
# <a id="ch6"></a>
# ## Scaling and train test split
# <hr/>
# Now we are ready to train a model and predict the required solution. There are 60+ predictive modelling algorithms to choose from. We must understand the type of problem and solution requirement to narrow down to a select few models which we can evaluate. Our problem is a mean squared error regression problem. We are also performing a category of machine learning which is called supervised learning as we are training our model with a given dataset.

# %%
# Features
X = df.drop('price',axis=1)

# Label
y = df['price']

# Split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (15129, 19)
# (6484, 19)
# (15129,)
# (6484,)

# %%
X_train
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 6560          3       2.50         1920      4534     2.0           0     0
# 10802         4       2.50         2620      8331     2.0           0     0
# 8989          3       2.50         1590      4094     2.0           0     0
# 1761          5       2.75         2540      5022     1.0           0     0
# 5749          4       2.50         3830     11972     1.0           1     4
# ...         ...        ...          ...       ...     ...         ...   ...
# 5695          3       2.25         1920      9672     2.0           0     0
# 8006          3       1.00         1240      3600     1.5           0     0
# 17745         3       2.25         1780      7332     2.0           0     0
# 17931         2       1.00         1150      5000     1.0           0     0
# 13151         3       1.00         1450      7930     1.0           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 6560           3      8        1920              0      1986             0
# 10802          3      9        2620              0      1991             0
# 8989           3      7        1590              0      1991             0
# 1761           4      8        1540           1000      1955             0
# 5749           3     11        2370           1460      1981             0
# ...          ...    ...         ...            ...       ...           ...
# 5695           4      8        1920              0      1984             0
# 8006           3      7        1240              0      1902             0
# 17745          3      7        1780              0      1987             0
# 17931          4      7        1050            100      1924             0
# 13151          4      6        1150            300      1923             0
#
#            lat     long  sqft_living15  sqft_lot15  month  year
# 6560   47.7144 -122.204           1380        5100      2  2015
# 10802  47.4357 -122.159           2760        8174      7  2014
# 8989   47.6100 -122.293           1940        3924      8  2014
# 1761   47.5593 -122.300           2510        5182      7  2014
# 5749   47.7404 -122.284           3080       12297      4  2015
# ...        ...      ...            ...         ...    ...   ...
# 5695   47.6233 -122.046           1950       10125      5  2015
# 8006   47.5986 -122.298           1680        3600      4  2015
# 17745  47.3593 -122.051           1510        7625     10  2014
# 17931  47.6846 -122.317           1463        4320      9  2014
# 13151  47.5212 -122.371           1040        7740      3  2015
#
# [15129 rows x 19 columns]

# %% [markdown]
# ### Normalizing / scaling the data
# We scale the feature data. To prevent data leakage from the test set, we only fit our scaler to the training set.

# %%
scaler = MinMaxScaler()

# fit and transfrom
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# everything has been scaled between 1 and 0
print('Max: ',X_train.max())
print('Min: ', X_train.min())
# Out:
# Max:  1.0000000000000002
# Min:  0.0

# %% [markdown]
# <a id="ch7"></a>
# ## Creating a model
# ***
# We estimate the number of neurons (units) from our features. Ex: X_train.shape (15117, 19). The optimizer is asking how you want to perform this gradient descent. In this case we are using the Adam optimizer and the mean square error loss function.

# %%
model = Sequential()

# input layer
model.add(Dense(19,activation='relu'))

# hidden layers
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

# output layer
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %% [markdown]
# <a id="ch8"></a>
# ## Training the model
# ***
# Now that the model is ready, we can fit the model into the data.
#
# Since the dataset is large, we are going to use batch_size. It is typical to use batches of the power of 2 (32, 64, 128, 256...). In this case we are using 128. The smaller the batch size, the longer is going to take.

# %%
model.fit(x=X_train,y=y_train.values,
          validation_data=(X_test,y_test.values),
          batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 1s 3ms/step - loss: 423628013568.0000 - val_loss: 433024991232.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 2ms/step - loss: 422748389376.0000 - val_loss: 429839712256.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 2ms/step - loss: 409714917376.0000 - val_loss: 398672953344.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 2ms/step - loss: 342308814848.0000 - val_loss: 283989278720.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 2ms/step - loss: 196812619776.0000 - val_loss: 134668124160.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 2ms/step - loss: 107225071616.0000 - val_loss: 104625168384.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 2ms/step - loss: 98381488128.0000 - val_loss: 102700802048.0000
# Epoch 8/400
# 119/119 [==============================] - 0s 2ms/step - loss: 96907526144.0000 - val_loss: 101149966336.0000
# Epoch 9/400
# 119/119 [==============================] - 0s 2ms/step - loss: 95415353344.0000 - val_loss: 99514499072.0000
# Epoch 10/400
# 119/119 [==============================] - 0s 2ms/step - loss: 93926301696.0000 - val_loss: 97855143936.0000
# Epoch 11/400
# 119/119 [==============================] - 0s 2ms/step - loss: 92366086144.0000 - val_loss: 96203923456.0000
# Epoch 12/400
# 119/119 [==============================] - 0s 2ms/step - loss: 90799112192.0000 - val_loss: 94441488384.0000
# Epoch 13/400
# 119/119 [==============================] - 0s 2ms/step - loss: 89127927808.0000 - val_loss: 92621635584.0000
# Epoch 14/400
# 119/119 [==============================] - 0s 2ms/step - loss: 87410081792.0000 - val_loss: 90674749440.0000
# Epoch 15/400
# 119/119 [==============================] - 0s 2ms/step - loss: 85610602496.0000 - val_loss: 88716075008.0000
# Epoch 16/400
# 119/119 [==============================] - 0s 2ms/step - loss: 83721601024.0000 - val_loss: 86625787904.0000
# Epoch 17/400
# 119/119 [==============================] - 0s 2ms/step - loss: 81751302144.0000 - val_loss: 84420386816.0000
# Epoch 18/400
# 119/119 [==============================] - 0s 2ms/step - loss: 79715680256.0000 - val_loss: 82205376512.0000
# Epoch 19/400
# 119/119 [==============================] - 0s 2ms/step - loss: 77511385088.0000 - val_loss: 79817261056.0000
400
# 119/119 [==============================] - 0s 2ms/step - loss: 29008357376.0000 - val_loss: 28851578880.0000
# Epoch 360/400
# 119/119 [==============================] - 0s 2ms/step - loss: 29048797184.0000 - val_loss: 28732751872.0000
# Epoch 361/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28981557248.0000 - val_loss: 28730587136.0000
# Epoch 362/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28943716352.0000 - val_loss: 28777885696.0000
# Epoch 363/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28943990784.0000 - val_loss: 28693643264.0000
# Epoch 364/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28941244416.0000 - val_loss: 28686112768.0000
# Epoch 365/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28913229824.0000 - val_loss: 28703741952.0000
# Epoch 366/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28893083648.0000 - val_loss: 28663517184.0000
# Epoch 367/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28879779840.0000 - val_loss: 28654100480.0000
# Epoch 368/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28868382720.0000 - val_loss: 28805386240.0000
# Epoch 369/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28868718592.0000 - val_loss: 28632309760.0000
# Epoch 370/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28847853568.0000 - val_loss: 28787220480.0000
# Epoch 371/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28878661632.0000 - val_loss: 28598919168.0000
# Epoch 372/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28828932096.0000 - val_loss: 28867569664.0000
# Epoch 373/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28853202944.0000 - val_loss: 28666378240.0000
# Epoch 374/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28777814016.0000 - val_loss: 28593205248.0000
# Epoch 375/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28778801152.0000 - val_loss: 28565932032.0000
# Epoch 376/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28781647872.0000 - val_loss: 28548806656.0000
# Epoch 377/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28738959360.0000 - val_loss: 28525621248.0000
# Epoch 378/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28751630336.0000 - val_loss: 28534171648.0000
# Epoch 379/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28705906688.0000 - val_loss: 28621006848.0000
# Epoch 380/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28689301504.0000 - val_loss: 28593369088.0000
# Epoch 381/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28680714240.0000 - val_loss: 28537817088.0000
# Epoch 382/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28681185280.0000 - val_loss: 28511084544.0000
# Epoch 383/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28634382336.0000 - val_loss: 28529860608.0000
# Epoch 384/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28766676992.0000 - val_loss: 28476217344.0000
# Epoch 385/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28646739968.0000 - val_loss: 28449503232.0000
# Epoch 386/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28579201024.0000 - val_loss: 28489013248.0000
# Epoch 387/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28568408064.0000 - val_loss: 28451655680.0000
# Epoch 388/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28596086784.0000 - val_loss: 28443746304.0000
# Epoch 389/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28547371008.0000 - val_loss: 28409995264.0000
# Epoch 390/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28579418112.0000 - val_loss: 28421445632.0000
# Epoch 391/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28527511552.0000 - val_loss: 28403304448.0000
# Epoch 392/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28565755904.0000 - val_loss: 28506712064.0000
# Epoch 393/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28506773504.0000 - val_loss: 28373454848.0000
# Epoch 394/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28472033280.0000 - val_loss: 28364498944.0000
# Epoch 395/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28450945024.0000 - val_loss: 28375814144.0000
# Epoch 396/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28436709376.0000 - val_loss: 28343072768.0000
# Epoch 397/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28411330560.0000 - val_loss: 28376856576.0000
# Epoch 398/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28398950400.0000 - val_loss: 28430073856.0000
# Epoch 399/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28395079680.0000 - val_loss: 28380549120.0000
# Epoch 400/400
# 119/119 [==============================] - 0s 2ms/step - loss: 28396912640.0000 - val_loss: 28313444352.0000

# %% [markdown]
# ### Training loss per epoch
# * This plot shows the training loss per epoch.
# * This plot helps us to see if there is overfitting in the model. In this case there is no overfitting because both lines go down at the same time.

# %%
losses = pd.DataFrame(model.history.history)

plt.figure(figsize=(15,5))
sns.lineplot(data=losses,lw=3)
plt.xlabel('Epochs')
plt.ylabel('')
plt.title('Training Loss per Epoch')
sns.despine()

# %% [markdown]
# <a id="ch9"></a>
# ## Evaluation on test data
# ---
# ### Regression Evaluation Metrics
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.

# %% [markdown]
# ### Predicting on brand new data
# In this part we are giving the model the test set to get a list of predictions. Then we compare the correct values with the list of predictions. We use different metrics to compare the predictions, in this case we use MAE, MSE, RMSE and Variance Regression Score.
#
# Let us start by analyzing the MAE, which is \\$103,500. This means that our model is off on average about \\$100,000.
#
# ***Is that MAE good or bad?***
#
# For that we must take into account our original data set and see what kind of values we have. For instance, the mean is 540,000, therefore the MEA is about 19% of the mean price. This is not a particularly good result.
#
# To better understand this error, we can use the variance regression score, where the best possible score is 1.0 and lower values are worse. This tells you how much variance is being explain by your model. In our case we have 0.80 which is a normal result.

# %%
# predictions on the test set
predictions = model.predict(X_test)

print('MAE: ',mean_absolute_error(y_test,predictions))
print('MSE: ',mean_squared_error(y_test,predictions))
print('RMSE: ',np.sqrt(mean_squared_error(y_test,predictions)))
print('Variance Regression Score: ',explained_variance_score(y_test,predictions))

print('\n\nDescriptive Statistics:\n',df['price'].describe())
# Out:
# 203/203 [==============================] - 0s 980us/step
# MAE:  104653.31893892659
# MSE:  28313447199.60434
# RMSE:  168266.0013181639
# Variance Regression Score:  0.7981690402021588
#
#
# Descriptive Statistics:
#  count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %% [markdown]
# ### Model predictions vs perfect fit
# * We can compare the model predictions with a perfect fit to see how accurate the model is.
# * The red line represents the perfect prediction.
# * We are being punish by the outliers, which are the expensive houses. Our model is not good predicting luxury houses.
# * On the other hand, our model is good predicting the price of houses between o and \\$2 million. There is clearly a good fit.
# * It may be worth it retraining our model just on price houses below \\$3 million.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))

# Our model predictions
plt.scatter(y_test,predictions)

# Perfect predictions
plt.plot(y_test,y_test,'r')

errors = y_test.values.reshape(6484, 1) - predictions
sns.distplot(errors, ax=axes[0])

sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Error', ylabel='', title='Error Histogram')
axes[1].set(xlabel='Test True Y', ylabel='Model Predictions', title='Model Predictions vs Perfect Fit')
# Out:
# C:\Users\SISTEMAS\AppData\Local\Temp\ipykernel_31880\3744242700.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(errors, ax=axes[0])
# [Text(0.5, 0, 'Test True Y'),
#  Text(0, 0.5, 'Model Predictions'),
#  Text(0.5, 1.0, 'Model Predictions vs Perfect Fit')]

# %% [markdown]
# <a id="ch10"></a>
# ## Predicting on a brand new house
# ---
# We are going to use the model to predict the price on a brand-new house. We are going to choose the first house of the data set and drop the price. single_house is going to have all the features that we need to predict the price. After that we need to reshape the variable and scale the features.
#
# The original price is \\$221,900 and the model prediction is \\$280,000.

# %%
# fueatures of new house
single_house = df.drop('price',axis=1).iloc[0]
print(f'Features of new house:\n{single_house}')

# reshape the numpy array and scale the features
single_house = scaler.transform(single_house.values.reshape(-1, 19))

# run the model and get the price prediction
print('\nPrediction Price:',model.predict(single_house)[0,0])

# original price
print('\nOriginal Price:',df.iloc[0]['price'])
# Out:
# Features of new house:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# month              10.0000
# year             2014.0000
# Name: 0, dtype: float64
# 1/1 [==============================] - 0s 25ms/step
#
# Prediction Price: 288447.2
#
# Original Price: 221900.0
# c:\Users\SISTEMAS\MLOPS-PROJECT\.venv\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## References
# * [An Introduction to Statistical Learning with Applications in R](http://faculty.marshall.usc.edu/gareth-james/ISL/) - This book provides an introduction to statistical learning methods.
# * [Python for Data Science and Machine Learning Bootcamp](https://www.udemy.com/course/python-for-data-science-and-machine-learning-bootcamp/) - Use Python for Data Science and Machine Learning.

# %% [markdown]
# **Thank you** for taking the time to read through my first exploration of a Kaggle dataset. I look forward to doing more!
#
# If you have a question or feedback, do not hesitate to comment and if you like this kernel,<b><font color='green'> please upvote! </font></b>
